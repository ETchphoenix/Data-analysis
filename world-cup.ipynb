# %% [markdown]
# <a href="https://www.kaggle.com/code/heshamibrahem/world-cup?scriptVersionId=115764540" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/fifa-world-cup-2022-complete-dataset/Fifa_world_cup_matches.csv

# %%
df = pd.read_csv("/kaggle/input/fifa-world-cup-2022-complete-dataset/Fifa_world_cup_matches.csv")
df
# Out:
#             team1         team2 possession team1 possession team2  \
# 0           QATAR       ECUADOR              42%              50%
# 1         ENGLAND          IRAN              72%              19%
# 2         SENEGAL   NETHERLANDS              44%              45%
# 3   UNITED STATES         WALES              51%              39%
# 4       ARGENTINA  SAUDI ARABIA              64%              24%
# ..            ...           ...              ...              ...
# 59        ENGLAND        FRANCE              54%              36%
# 60      ARGENTINA       CROATIA              34%              54%
# 61         FRANCE       MOROCCO              34%              55%
# 62        CROATIA       MOROCCO              45%              45%
# 63      ARGENTINA        FRANCE              46%              40%
#
#    possession in contest  number of goals team1  number of goals team2  \
# 0                     8%                      0                      2
# ...

# %%
def infoo(df):
    df.info() # getting data frame information
    print("-" * 50)
    print(f"number of rows: {df.shape[0]}") # dataframe rows number
    print("-" * 50)
    print(f"number of columns: {df.shape[1]}") # dataframe columns number
    print("-" * 50)
    for c in df.columns:
        if df[c].dtype == 'float' or df[c].dtype == 'int': # if numerical values
            print("the values of {} are within range {} to {}".format(c,df[c].min(),df[c].max())) # get range
            print("-" * 50)
        else: # string or categorial values
            print("Number of Unique value of {} is: {}".format(c, len(df[c].unique()))) # get number of unqiue value
            print("Unique value of {} is: {}".format(c, df[c].unique())) # get unique values
            print("-" * 50)
    for c in df.columns:
        print("Nan number in {} is: {}".format(c, df[c].isna().sum())) # collect nan values
        print("-" * 50)

# %%
infoo(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 88 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   team1                                                  64 non-null     object
#  1   team2                                                  64 non-null     object
#  2   possession team1                                       64 non-null     object
#  3   possession team2                                       64 non-null     object
#  4   possession in contest                                  64 non-null     object
#  5   number of goals team1                                  64 non-null     int64
#  6   number of goals team2                                  64 non-null     int64
#  7   date                                                   64 non-null     object
# ...

# %% [markdown]
# Fix columns

# %%
columnss = list(df.columns)
for c in columnss:
    df = df.rename(columns={c:' '.join(c.split())})
df.columns
# Out:
# Index(['team1', 'team2', 'possession team1', 'possession team2',
#        'possession in contest', 'number of goals team1',
#        'number of goals team2', 'date', 'hour', 'category',
#        'total attempts team1', 'total attempts team2', 'conceded team1',
#        'conceded team2', 'goal inside the penalty area team1',
#        'goal inside the penalty area team2',
#        'goal outside the penalty area team1',
#        'goal outside the penalty area team2', 'assists team1', 'assists team2',
#        'on target attempts team1', 'on target attempts team2',
#        'off target attempts team1', 'off target attempts team2',
#        'attempts inside the penalty area team1',
#        'attempts inside the penalty area team2',
#        'attempts outside the penalty area team1',
#        'attempts outside the penalty area team2', 'left channel team1',
#        'left channel team2', 'left inside channel team1',
#        'left inside channel team2', 'central channel team1',
# ...

# %%
cc = list(df.columns)
ccc = list(df.columns)
for c in ccc:
    if (' team1' in c) or (' team2' in c):
        cc.remove(c)
cc
# Out:
# ['team1',
#  'team2',
#  'possession in contest',
#  'date',
#  'hour',
#  'category',
#  'completed line breaksteam1',
#  'completed defensive line breaksteam1']

# %%
df = df.rename(columns={'completed line breaksteam1':'completed line breaks team1', 'completed defensive line breaksteam1':'completed defensive line breaks team1'})

# %%
df.columns #check everthing is fixed
# Out:
# Index(['team1', 'team2', 'possession team1', 'possession team2',
#        'possession in contest', 'number of goals team1',
#        'number of goals team2', 'date', 'hour', 'category',
#        'total attempts team1', 'total attempts team2', 'conceded team1',
#        'conceded team2', 'goal inside the penalty area team1',
#        'goal inside the penalty area team2',
#        'goal outside the penalty area team1',
#        'goal outside the penalty area team2', 'assists team1', 'assists team2',
#        'on target attempts team1', 'on target attempts team2',
#        'off target attempts team1', 'off target attempts team2',
#        'attempts inside the penalty area team1',
#        'attempts inside the penalty area team2',
#        'attempts outside the penalty area team1',
#        'attempts outside the penalty area team2', 'left channel team1',
#        'left channel team2', 'left inside channel team1',
#        'left inside channel team2', 'central channel team1',
# ...

# %%
home = list(df['team1'].unique())
home
# Out:
# ['QATAR',
#  'ENGLAND',
#  'SENEGAL',
#  'UNITED STATES',
#  'ARGENTINA',
#  'DENMARK',
#  'MEXICO',
#  'FRANCE',
#  'MOROCCO',
#  'GERMANY',
#  'SPAIN',
#  'BELGIUM',
#  'SWITZERLAND',
#  'URUGUAY',
#  'PORTUGAL',
#  'BRAZIL',
#  'WALES',
#  'NETHERLANDS',
#  'TUNISIA',
#  'POLAND',
#  'JAPAN',
#  'CROATIA',
#  'CAMEROON',
#  'KOREA REPUBLIC',
#  'ECUADOR',
#  'IRAN',
#  'AUSTRALIA',
#  'SAUDI ARABIA',
#  'CANADA',
#  'COSTA RICA',
#  'GHANA',
#  'SERBIA']

# %%
away = list(df['team2'].unique())
away
# Out:
# ['ECUADOR',
#  'IRAN',
#  'NETHERLANDS',
#  'WALES',
#  'SAUDI ARABIA',
#  'TUNISIA',
#  'POLAND',
#  'AUSTRALIA',
#  'CROATIA',
#  'JAPAN',
#  'COSTA RICA',
#  'CANADA',
#  'CAMEROON',
#  'KOREA REPUBLIC',
#  'GHANA',
#  'SERBIA',
#  'SENEGAL',
#  'UNITED STATES',
#  'DENMARK',
#  'MEXICO',
#  'MOROCCO',
#  'GERMANY',
#  'SWITZERLAND',
#  'URUGUAY',
#  'QATAR',
#  'ENGLAND',
#  'FRANCE',
#  'ARGENTINA',
#  'BELGIUM',
#  'SPAIN',
#  'PORTUGAL',
#  'BRAZIL']

# %%
for h in home:
    if h in away:
        print("yes")
    else:
        print("NO "+h)
# Out:
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes

# %%
parti_teams = home
parti_teams
# Out:
# ['QATAR',
#  'ENGLAND',
#  'SENEGAL',
#  'UNITED STATES',
#  'ARGENTINA',
#  'DENMARK',
#  'MEXICO',
#  'FRANCE',
#  'MOROCCO',
#  'GERMANY',
#  'SPAIN',
#  'BELGIUM',
#  'SWITZERLAND',
#  'URUGUAY',
#  'PORTUGAL',
#  'BRAZIL',
#  'WALES',
#  'NETHERLANDS',
#  'TUNISIA',
#  'POLAND',
#  'JAPAN',
#  'CROATIA',
#  'CAMEROON',
#  'KOREA REPUBLIC',
#  'ECUADOR',
#  'IRAN',
#  'AUSTRALIA',
#  'SAUDI ARABIA',
#  'CANADA',
#  'COSTA RICA',
#  'GHANA',
#  'SERBIA']

# %% [markdown]
# Now we got all the teams that participate in the world cup

# %% [markdown]
# Now let's get rid of the possision issue to covert it to float

# %%
for n in df.index:
    df['possession team1'].loc[n] = df['possession team1'].loc[n].replace('%', '')
    df['possession team2'].loc[n] = df['possession team2'].loc[n].replace('%', '')
    df['possession in contest'].loc[n] = df['possession in contest'].loc[n].replace('%', '')
df
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#             team1         team2 possession team1 possession team2  \
# 0           QATAR       ECUADOR               42               50
# 1         ENGLAND          IRAN               72               19
# 2         SENEGAL   NETHERLANDS               44               45
# 3   UNITED STATES         WALES               51               39
# 4       ARGENTINA  SAUDI ARABIA               64               24
# ..            ...           ...              ...              ...
# 59        ENGLAND        FRANCE               54               36
# 60      ARGENTINA       CROATIA               34               54
# ...

# %%
df['possession team1'] = df['possession team1'].astype('float')
df['possession team2'] = df['possession team2'].astype('float')
df['possession in contest'] = df['possession in contest'].astype('float')
df['possession team1'] = df['possession team1']/100
df['possession team2'] = df['possession team2']/100
df['possession in contest'] = df['possession in contest']/100
df.head()
# Out:
#            team1         team2  possession team1  possession team2  \
# 0          QATAR       ECUADOR              0.42              0.50
# 1        ENGLAND          IRAN              0.72              0.19
# 2        SENEGAL   NETHERLANDS              0.44              0.45
# 3  UNITED STATES         WALES              0.51              0.39
# 4      ARGENTINA  SAUDI ARABIA              0.64              0.24
#
#    possession in contest  number of goals team1  number of goals team2  \
# 0                   0.08                      0                      2
# 1                   0.09                      6                      2
# 2                   0.11                      0                      2
# 3                   0.10                      1                      1
# 4                   0.12                      1                      2
#
#           date     hour category  ...  penalties scored team1  \
# 0  20 NOV 2022  17 : 00  Group A  ...                       0
# ...

# %% [markdown]
# Now get rid of unnecessary things

# %%
df = df.drop(['date','hour','category'],axis=1)
df.head()
# Out:
#            team1         team2  possession team1  possession team2  \
# 0          QATAR       ECUADOR              0.42              0.50
# 1        ENGLAND          IRAN              0.72              0.19
# 2        SENEGAL   NETHERLANDS              0.44              0.45
# 3  UNITED STATES         WALES              0.51              0.39
# 4      ARGENTINA  SAUDI ARABIA              0.64              0.24
#
#    possession in contest  number of goals team1  number of goals team2  \
# 0                   0.08                      0                      2
# 1                   0.09                      6                      2
# 2                   0.11                      0                      2
# 3                   0.10                      1                      1
# 4                   0.12                      1                      2
#
#    total attempts team1  total attempts team2  conceded team1  ...  \
# ...

# %%
new_table = (['team']+list(df.columns[2:]))
new_table
# Out:
# ['team',
#  'possession team1',
#  'possession team2',
#  'possession in contest',
#  'number of goals team1',
#  'number of goals team2',
#  'total attempts team1',
#  'total attempts team2',
#  'conceded team1',
#  'conceded team2',
#  'goal inside the penalty area team1',
#  'goal inside the penalty area team2',
#  'goal outside the penalty area team1',
#  'goal outside the penalty area team2',
#  'assists team1',
#  'assists team2',
#  'on target attempts team1',
#  'on target attempts team2',
#  'off target attempts team1',
#  'off target attempts team2',
#  'attempts inside the penalty area team1',
#  'attempts inside the penalty area team2',
#  'attempts outside the penalty area team1',
#  'attempts outside the penalty area team2',
#  'left channel team1',
#  'left channel team2',
#  'left inside channel team1',
#  'left inside channel team2',
#  'central channel team1',
#  'central channel team2',
#  'right inside channel team1',
#  'right inside channel team2',
# ...

# %%
new_df = pd.DataFrame(columns= new_table)

# %%
new_df
# Out:
# Empty DataFrame
# ...

# %%
new_df['team'] = parti_teams

# %%
new_df
# Out:
#               team possession team1 possession team2 possession in contest  \
# 0            QATAR              NaN              NaN                   NaN
# 1          ENGLAND              NaN              NaN                   NaN
# 2          SENEGAL              NaN              NaN                   NaN
# 3    UNITED STATES              NaN              NaN                   NaN
# 4        ARGENTINA              NaN              NaN                   NaN
# 5          DENMARK              NaN              NaN                   NaN
# 6           MEXICO              NaN              NaN                   NaN
# 7           FRANCE              NaN              NaN                   NaN
# 8          MOROCCO              NaN              NaN                   NaN
# 9          GERMANY              NaN              NaN                   NaN
# 10           SPAIN              NaN              NaN                   NaN
# ...

# %% [markdown]
# Get possession average for each nation team

# %% [markdown]
# First replace nan with 0

# %%
new_df = new_df.fillna(0)
new_df
# Out:
#               team  possession team1  possession team2  possession in contest  \
# 0            QATAR                 0                 0                      0
# 1          ENGLAND                 0                 0                      0
# 2          SENEGAL                 0                 0                      0
# 3    UNITED STATES                 0                 0                      0
# 4        ARGENTINA                 0                 0                      0
# 5          DENMARK                 0                 0                      0
# 6           MEXICO                 0                 0                      0
# 7           FRANCE                 0                 0                      0
# 8          MOROCCO                 0                 0                      0
# 9          GERMANY                 0                 0                      0
# 10           SPAIN                 0                 0                      0
# ...

# %%
c = new_df.columns[1:] # columns to fill
for i in new_df.index:
    team1 = df[df['team1'] == new_df['team'].loc[i]]
    team2 = df[df['team2'] == new_df['team'].loc[i]]
    for co in c:
        if 'possession' in co:
            if 'team1' in co:
                new_df[co].loc[i] = team1[co].mean()
            else:
                new_df[co].loc[i] = team2[co].mean()
        else:
            if 'team1' in co:
                new_df[co].loc[i] = team1[co].sum()
            else:
                new_df[co].loc[i] = team2[co].sum()
new_df
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#               team  possession team1  possession team2  possession in contest  \
# 0            QATAR          0.420000          0.380000               0.080000
# 1          ENGLAND          0.577500          0.580000               0.100000
# 2          SENEGAL          0.440000          0.383333               0.126667
# 3    UNITED STATES          0.510000          0.463333               0.116667
# 4        ARGENTINA          0.494000          0.555000               0.100000
# 5          DENMARK          0.550000          0.520000               0.140000
# ...

# %%
new_df['possession'] = (new_df['possession team1']+ new_df['possession team2'])/2
new_df.drop(['possession team1','possession team2'],axis=1, inplace=True)
c = new_df.columns[1:]
for co in c:
    if 'team1' in co: #to make it once
        new_co = co.replace(' team1','')
        new_df[new_co] = new_df[new_co+' team1']+ new_df[new_co+' team2']
        new_df.drop([new_co+' team1',new_co+' team2'],axis=1, inplace=True)
new_df
# Out:
#               team  possession in contest  possession  number of goals  \
# 0            QATAR               0.080000    0.400000                1
# 1          ENGLAND               0.100000    0.578750               13
# 2          SENEGAL               0.126667    0.411667                5
# 3    UNITED STATES               0.116667    0.486667                3
# 4        ARGENTINA               0.100000    0.524500               15
# 5          DENMARK               0.140000    0.535000                1
# 6           MEXICO               0.155000    0.497500                2
# 7           FRANCE               0.126667    0.447500               16
# 8          MOROCCO               0.112500    0.336667                6
# 9          GERMANY               0.120000    0.557500                6
# 10           SPAIN               0.090000    0.690000                9
# 11         BELGIUM               0.100000    0.490000                1
# ...

# %%
#New columns
new_df[['win','loss','draw']] =[0,0,0]

# %%
for i in new_df.index:
    team1 = df[df['team1'] == new_df['team'].loc[i]]
    team2 = df[df['team2'] == new_df['team'].loc[i]]
    for l in team1.index:
        if team1['number of goals team1'].loc[l] > team1['number of goals team2'].loc[l]:
            new_df['win'].loc[i] += 1
        elif team1['number of goals team2'].loc[l] > team1['number of goals team1'].loc[l]:
            new_df['loss'].loc[i] += 1
        else:
            new_df['draw'].loc[i] += 1
    for l in team2.index:
        if team2['number of goals team2'].loc[l] > team2['number of goals team1'].loc[l]:
            new_df['win'].loc[i] += 1
        elif team2['number of goals team1'].loc[l] > team2['number of goals team2'].loc[l]:
            new_df['loss'].loc[i] += 1
        else:
            new_df['draw'].loc[i] += 1
new_df['number_of_matches'] = new_df['win'] + new_df['loss'] + new_df['draw']
new_df
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#               team  possession in contest  possession  number of goals  \
# 0            QATAR               0.080000    0.400000                1
# 1          ENGLAND               0.100000    0.578750               13
# 2          SENEGAL               0.126667    0.411667                5
# 3    UNITED STATES               0.116667    0.486667                3
# 4        ARGENTINA               0.100000    0.524500               15
# 5          DENMARK               0.140000    0.535000                1
# 6           MEXICO               0.155000    0.497500                2
# ...

# %%
new_df[['team','win','loss','draw','number_of_matches']]
# Out:
#               team  win  loss  draw  number_of_matches
# 0            QATAR    0     3     0                  3
# 1          ENGLAND    3     1     1                  5
# 2          SENEGAL    2     2     0                  4
# 3    UNITED STATES    1     1     2                  4
# 4        ARGENTINA    4     1     2                  7
# 5          DENMARK    0     2     1                  3
# 6           MEXICO    1     1     1                  3
# 7           FRANCE    5     1     1                  7
# 8          MOROCCO    3     2     2                  7
# 9          GERMANY    1     1     1                  3
# 10           SPAIN    1     1     2                  4
# 11         BELGIUM    1     1     1                  3
# 12     SWITZERLAND    2     2     0                  4
# 13         URUGUAY    1     1     1                  3
# 14        PORTUGAL    3     2     0                  5
# 15          BRAZIL    3     1     1                  5
# ...

# %%
new_df['possession in contest'] = new_df['possession in contest']*100
new_df['possession'] = new_df['possession']*100
new_df
# Out:
#               team  possession in contest  possession  number of goals  \
# 0            QATAR               8.000000   40.000000                1
# 1          ENGLAND              10.000000   57.875000               13
# 2          SENEGAL              12.666667   41.166667                5
# 3    UNITED STATES              11.666667   48.666667                3
# 4        ARGENTINA              10.000000   52.450000               15
# 5          DENMARK              14.000000   53.500000                1
# 6           MEXICO              15.500000   49.750000                2
# 7           FRANCE              12.666667   44.750000               16
# 8          MOROCCO              11.250000   33.666667                6
# 9          GERMANY              12.000000   55.750000                6
# 10           SPAIN               9.000000   69.000000                9
# 11         BELGIUM              10.000000   49.000000                1
# ...

# %%
new_df.to_csv('new.csv')
